# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('heart_failure_clinical_records_dataset.csv')
features=data.columns

# %%
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
features
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
death_data=data.loc[data['DEATH_EVENT']==1]

# %%
death_data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 220  73.0        0                       582         0                 20
# 230  60.0        0                       166         0                 30
# 246  55.0        0                      2017         0                 25
# 262  65.0        1                       258         1                 25
# 266  55.0        0                      1199         0                 20
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
survive_data=data.loc[data['DEATH_EVENT']==0]
survive_data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 14   49.0        1                        80         0                 30
# 20   65.0        1                        52         0                 25
# 23   53.0        0                        63         1                 60
# 33   50.0        1                       159         1                 30
# 38   60.0        0                      2656         1                 30
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
death_data[['creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','serum_sodium','time','age']].mean()
# Out:
# creatinine_phosphokinase       670.197917
# ejection_fraction               33.468750
# platelets                   256381.044792
# serum_creatinine                 1.835833
# serum_sodium                   135.375000
# time                            70.885417
# age                             65.215281
# dtype: float64

# %%
survive_data[['creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','serum_sodium','time','age']].mean()
# Out:
# creatinine_phosphokinase       540.054187
# ejection_fraction               40.266010
# platelets                   266657.489901
# serum_creatinine                 1.184877
# serum_sodium                   137.216749
# time                           158.339901
# age                             58.761906
# dtype: float64

# %%
d_platelets_box_plot=death_data.boxplot(column='platelets')

# %%
s_platelets_box_plot=survive_data.boxplot(column='platelets')

# %%
fig1,ax1=plt.subplots()
ax1.set_title('creatinine phosphokinase')
plot1=ax1.boxplot([death_data['creatinine_phosphokinase'],survive_data['creatinine_phosphokinase']],showfliers=False)

# %%
fig2,ax2=plt.subplots()
ax2.set_title('Ejection Fraction')
plot2=ax2.boxplot([death_data['ejection_fraction'],survive_data['ejection_fraction']],showfliers=False)

# %%
fig3,ax3=plt.subplots()
ax3.set_title('Platelets Counts')
plot3=ax3.boxplot([death_data['platelets'],survive_data['platelets']],showfliers=False)

# %%
fig4,ax4=plt.subplots()
ax4.set_title('Creatinine Levels')
plot4=ax4.boxplot([death_data['serum_creatinine'],survive_data['serum_creatinine']],showfliers=False)

# %%
fig5,ax5=plt.subplots()
ax5.set_title('Sodium Levels')
plot5=ax5.boxplot([death_data['serum_sodium'],survive_data['serum_sodium']],showfliers=False)

# %%
fig6,ax6=plt.subplots()
ax6.set_title('Age')
plot6=ax6.boxplot([death_data['age'],survive_data['age']],showfliers=False)

# %%
fig7,ax7=plt.subplots()
ax7.set_title('Time')
plot7=ax7.boxplot([death_data['time'],survive_data['time']],showfliers=False)

# %%
from sklearn.feature_selection import chi2

# %%
chi_scores= chi2(data[['anaemia','diabetes','high_blood_pressure','sex','smoking']],data['DEATH_EVENT'])
chi_scores
# Out:
# (array([7.46593411e-01, 6.56814450e-04, 1.22153853e+00, 1.95626598e-03,
#         3.23468288e-02]),
#  array([0.38755692, 0.97955374, 0.26905893, 0.96472131, 0.85726857]))

# %%
from sklearn.feature_selection import f_classif
f_scores=f_classif(data[['creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','serum_sodium','time','age']],data['DEATH_EVENT'])
f_scores
# Out:
# (array([  1.17325872,  23.09406305,   0.71888045,  28.15849226,
#          11.76533129, 114.1812644 ,  20.43594646]),
#  array([2.79611246e-01, 2.45289742e-06, 3.97194154e-01, 2.19019785e-07,
#         6.88911236e-04, 9.12222338e-23, 8.91676295e-06]))

# %%
## Hence the features selected are ejection_fraction, serum_creatinine, serum_sodium, time, age, anaemia and high_blood_pressure
